# %%
import pandas as pd
import numpy as np
import seaborn as sns

import matplotlib.pylab as plt
from matplotlib.pyplot import imread
# %matplotlib inline

# %%
#table_27b = df_b
dfb = pd.read_excel('table_27b.xlsx',skiprows=2,inplace=True)

# %%
dfb.head()
# Out:
#    Income year2 Number of property interests1   Taxable income range4  \
# 0          2000                    1 interest    a. Less than $18,200
# 1          2000                    1 interest    b. $18,200 - $50,000
# 2          2000                    1 interest   c. $50,001 - $100,000
# 3          2000                    1 interest  d. $100,001 - $500,000
# 4          2000                    1 interest   e. More than $500,000
#
#    Number of individuals
# 0                 224737
# 1                 446165
# 2                 180129
# 3                  36569
# 4                   1500

# %%
#deleting unwanted string from the column "Number of property interests"
dfb['Number of property interests1'].replace(regex=True,inplace=True,to_replace=r'\D',value=r'')

# %%
dfb.head()
# Out:
#    Income year2 Number of property interests1   Taxable income range4  \
# 0          2000                             1    a. Less than $18,200
# 1          2000                             1    b. $18,200 - $50,000
# 2          2000                             1   c. $50,001 - $100,000
# 3          2000                             1  d. $100,001 - $500,000
# 4          2000                             1   e. More than $500,000
#
#    Number of individuals
# 0                 224737
# 1                 446165
# 2                 180129
# 3                  36569
# 4                   1500

# %%
dfb.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 540 entries, 0 to 539
# Data columns (total 4 columns):
# Income year2                     540 non-null int64
# Number of property interests1    540 non-null object
# Taxable income range4            540 non-null object
# Number of individuals            540 non-null int64
# dtypes: int64(2), object(2)
# memory usage: 17.0+ KB

# %%
dfb['Number of property interests1'] = dfb['Number of property interests1'].astype(int) # converting string to integer

# %%
dfb.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 540 entries, 0 to 539
# Data columns (total 4 columns):
# Income year2                     540 non-null int64
# Number of property interests1    540 non-null int32
# Taxable income range4            540 non-null object
# Number of individuals            540 non-null int64
# dtypes: int32(1), int64(2), object(1)
# memory usage: 14.9+ KB

# %%
dfb.describe()
# Out:
#        Income year2  Number of property interests1  Number of individuals
# count    540.000000                     540.000000             540.000000
# mean    2008.500000                       3.500000           54982.403704
# std        5.192938                       1.709409          110609.217806
# min     2000.000000                       1.000000              47.000000
# 25%     2004.000000                       2.000000            2553.250000
# 50%     2008.500000                       3.500000            6078.500000
# 75%     2013.000000                       5.000000           40296.500000
# max     2017.000000                       6.000000          530194.000000

# %% [markdown]
# # Exploratory Data Analysis
#
# Let's begin some exploratory data analysis! We'll start by checking out missing data!
#
# ## Missing Data
#
# We can use seaborn to create a simple heatmap to see where we are missing data!

# %%
sns.set_palette("Accent")# Accent, Accent_r, Blues, Blues_r, BrBG, BrBG_r, BuGn, BuGn_r, BuPu, BuPu_r, CMRmap, CMRmap_r, Dark2, Dark2_r, GnBu, GnBu_r, Greens, Greens_r, Greys, Greys_r, OrRd, OrRd_r, Oranges, Oranges_r, PRGn, PRGn_r, Paired, Paired_r, Pastel1, Pastel1_r, Pastel2, Pastel2_r, PiYG, PiYG_r, PuBu, PuBuGn, PuBuGn_r, PuBu_r, PuOr, PuOr_r, PuRd, PuRd_r, Purples, Purples_r, RdBu, RdBu_r
sns.set_style('darkgrid') #other values: white, dark, whitegrid, darkgrid, ticks
sns.set(rc={'figure.figsize':(22,12)})

# %%
sns.heatmap(dfb.isnull(),yticklabels=False,cbar=False,cmap='viridis')

# %%
sns.set_palette("Accent")
sns.set_style('darkgrid')
sns.pairplot(dfb)

# %% [markdown]
# ### Correlation HeatMap of the data

# %%
sns.heatmap(dfb.corr(), annot = True)
sns.set(rc={'figure.figsize':(22,12)})

# %%
dfb.columns
# Out:
# Index(['Income year2', 'Number of property interests1',
#        'Taxable income range4', 'Number of individuals'],
#       dtype='object')

# %%
sns.countplot(x='Taxable income range4',hue='Number of property interests1',data=dfb)
sns.set(rc={'figure.figsize':(36,16)})

# %%
from pandas.api.types import is_string_dtype
from pandas.api.types import is_numeric_dtype

# %%
plt.figure(figsize=(12, 7))
sns.boxplot(x='Taxable income range4',y='Number of individuals',data=dfb,palette='winter')
sns.set(rc={'figure.figsize':(22,14)})

# %%
sns.set_palette("Accent")
sns.set_style('darkgrid')
sns.jointplot(data=dfb, x='Income year2', y='Number of individuals')

# %%
sns.lmplot(data=dfb,x='Income year2',y='Number of individuals')

# %%
dfb.head(20)
# Out:
#     Income year2  Number of property interests1   Taxable income range4  \
# 0           2000                              1    a. Less than $18,200
# 1           2000                              1    b. $18,200 - $50,000
# 2           2000                              1   c. $50,001 - $100,000
# 3           2000                              1  d. $100,001 - $500,000
# 4           2000                              1   e. More than $500,000
# 5           2000                              2    a. Less than $18,200
# 6           2000                              2    b. $18,200 - $50,000
# 7           2000                              2   c. $50,001 - $100,000
# 8           2000                              2  d. $100,001 - $500,000
# 9           2000                              2   e. More than $500,000
# 10          2000                              3    a. Less than $18,200
# 11          2000                              3    b. $18,200 - $50,000
# ...

# %% [markdown]
# ## Filtering by Taxable Income Range

# %%
#filtering by Taxable income range = Less than $18,200 dollars
dfb_tir18  = dfb.loc[dfb['Taxable income range4'] == 'a. Less than $18,200']

# %%
dfb_tir18
# Out:
#      Income year2  Number of property interests1 Taxable income range4  \
# 0            2000                              1  a. Less than $18,200
# 5            2000                              2  a. Less than $18,200
# 10           2000                              3  a. Less than $18,200
# 15           2000                              4  a. Less than $18,200
# 20           2000                              5  a. Less than $18,200
# ..            ...                            ...                   ...
# 515          2017                              2  a. Less than $18,200
# 520          2017                              3  a. Less than $18,200
# 525          2017                              4  a. Less than $18,200
# 530          2017                              5  a. Less than $18,200
# 535          2017                              6  a. Less than $18,200
#
#      Number of individuals
# 0                   224737
# 5                    44155
# 10                   11504
# ...

# %%
sns.pairplot(dfb_tir18)

# %%
dfb_tir18.describe()
# Out:
#        Income year2  Number of property interests1  Number of individuals
# count    108.000000                     108.000000             108.000000
# mean    2008.500000                       3.500000           50610.194444
# std        5.212315                       1.715787           80699.372210
# min     2000.000000                       1.000000            1246.000000
# 25%     2004.000000                       2.000000            3035.000000
# 50%     2008.500000                       3.500000            9299.000000
# 75%     2013.000000                       5.000000           52290.750000
# max     2017.000000                       6.000000          240343.000000

# %%
sns.jointplot(data=dfb_tir18, x='Income year2', y='Number of individuals')

# %% [markdown]
# Number of individuals did not increase over the years whose income is below 18000 dollars

# %%
#filtering by Taxable income range = 18,200−50,000 dollars
dfb_tir  = dfb.loc[dfb['Taxable income range4'] == 'b. $18,200 - $50,000']

# %%
dfb_tir
# Out:
#      Income year2  Number of property interests1 Taxable income range4  \
# 1            2000                              1  b. $18,200 - $50,000
# 6            2000                              2  b. $18,200 - $50,000
# 11           2000                              3  b. $18,200 - $50,000
# 16           2000                              4  b. $18,200 - $50,000
# 21           2000                              5  b. $18,200 - $50,000
# ..            ...                            ...                   ...
# 516          2017                              2  b. $18,200 - $50,000
# 521          2017                              3  b. $18,200 - $50,000
# 526          2017                              4  b. $18,200 - $50,000
# 531          2017                              5  b. $18,200 - $50,000
# 536          2017                              6  b. $18,200 - $50,000
#
#      Number of individuals
# 1                   446165
# 6                    91788
# 11                   23578
# ...

# %%
sns.pairplot(dfb_tir)

# %%
dfb_tir.describe()
# Out:
#        Income year2  Number of property interests1  Number of individuals
# count    108.000000                     108.000000             108.000000
# mean    2008.500000                       3.500000           96142.703704
# std        5.212315                       1.715787          153993.948482
# min     2000.000000                       1.000000            2323.000000
# 25%     2004.000000                       2.000000            4309.000000
# 50%     2008.500000                       3.500000           17532.000000
# 75%     2013.000000                       5.000000          100381.250000
# max     2017.000000                       6.000000          450532.000000

# %%
sns.heatmap(dfb_tir.corr(), annot = True)

# %%
plt.figure(figsize=(12, 7))
sns.boxplot(x='Taxable income range4',y='Number of individuals',data=dfb_tir)

# %%
sns.distplot(dfb_tir['Number of individuals'], bins=10)

# %%
sns.jointplot(data=dfb_tir, x='Income year2', y='Number of individuals')

# %% [markdown]
# individual didn't increase over the years in the income range 18000-50000!

# %%
sns.lmplot(data=dfb_tir, x='Income year2', y='Number of individuals')

# %% [markdown]
# ### Linear Regression (Predicting number of individuals in future)

# %%
X = dfb_tir[['Income year2', 'Number of property interests1']]
y = dfb_tir[['Number of individuals']]

from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3)

#creating and training the model

from sklearn.linear_model import LinearRegression

lm = LinearRegression()
lm.fit(X_train,y_train)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None, normalize=False)

# %%
#prediction
predictions = lm.predict(X_test)
plt.scatter(y_test,predictions)

# %% [markdown]
# ### Model Evaluation

# %%
from sklearn import metrics
print('MAE:', metrics.mean_absolute_error(y_test, predictions))
print('MSE:', metrics.mean_squared_error(y_test, predictions))
print('RMSE:', np.sqrt(metrics.mean_squared_error(y_test, predictions)))
# Out:
# MAE: 75856.03543214222
# MSE: 8572895128.825975
# RMSE: 92589.92995367247

# %% [markdown]
# ## Analyzing who has number of property interest = 1 and income is 18000-50000 dollars

# %%
#Selecting who have number of property interst = 1
dfb_tir1= dfb_tir.loc[dfb_tir['Number of property interests1'] == 1]

# %%
dfb_tir1.head()
# Out:
#      Income year2  Number of property interests1 Taxable income range4  \
# 1            2000                              1  b. $18,200 - $50,000
# 31           2001                              1  b. $18,200 - $50,000
# 61           2002                              1  b. $18,200 - $50,000
# 91           2003                              1  b. $18,200 - $50,000
# 121          2004                              1  b. $18,200 - $50,000
#
#      Number of individuals
# 1                   446165
# 31                  445059
# 61                  448843
# 91                  449916
# 121                 450532

# %%
sns.pairplot(dfb_tir1)

# %%
sns.heatmap(dfb_tir1.corr(), annot = True)

# %%
sns.distplot(dfb_tir1['Number of individuals'], bins=10)

# %%
sns.jointplot(data=dfb_tir1, x='Income year2', y='Number of individuals')

# %% [markdown]
# Number of individuals decreased over the years who has property interest = 1

# %%
sns.lmplot(data=dfb_tir1, x='Income year2', y='Number of individuals')

# %% [markdown]
# It's clearly shown above that individuals decreased over the  years who has property interest = 1

# %%
dfb_tir1.head()
# Out:
#      Income year2  Number of property interests1 Taxable income range4  \
# 1            2000                              1  b. $18,200 - $50,000
# 31           2001                              1  b. $18,200 - $50,000
# 61           2002                              1  b. $18,200 - $50,000
# 91           2003                              1  b. $18,200 - $50,000
# 121          2004                              1  b. $18,200 - $50,000
#
#      Number of individuals
# 1                   446165
# 31                  445059
# 61                  448843
# 91                  449916
# 121                 450532

# %%
#Saving dfb_tir1 data frame as csv file to working with ARMA and ARIMA
dfb_tir1.to_csv('tir1.csv', encoding='utf-8', index=False)

# %% [markdown]
# ## ARMA and ARIMA

# %%
# Load specific forecasting tools
from statsmodels.tsa.arima_model import ARMA,ARMAResults,ARIMA,ARIMAResults
from statsmodels.graphics.tsaplots import plot_acf,plot_pacf # for determining (p,q) orders
from pmdarima import auto_arima # for determining ARIMA orders

# Ignore harmless warnings
import warnings
warnings.filterwarnings("ignore")

# %%
#Loading the file we saved
dfb_tir1_a = pd.read_csv('tir1.csv',index_col ='Income year2',parse_dates = True)
dfb_tir1_a.index.freq = 'YS'

# %%
dfb_tir1_a.head()
# Out:
#               Number of property interests1 Taxable income range4  \
# Income year2
# 2000-01-01                                1  b. $18,200 - $50,000
# 2001-01-01                                1  b. $18,200 - $50,000
# 2002-01-01                                1  b. $18,200 - $50,000
# 2003-01-01                                1  b. $18,200 - $50,000
# 2004-01-01                                1  b. $18,200 - $50,000
#
#               Number of individuals
# Income year2
# 2000-01-01                   446165
# 2001-01-01                   445059
# 2002-01-01                   448843
# 2003-01-01                   449916
# 2004-01-01                   450532

# %% [markdown]
# ## ARMA

# %%
dfb_tir1_a['Number of individuals'].plot(figsize=(12,5))

# %%
from statsmodels.tsa.stattools import adfuller

def adf_test(series,title=''):
    """
    Pass in a time series and an optional title, returns an ADF report
    """
    print(f'Augmented Dickey-Fuller Test: {title}')
    result = adfuller(series.dropna(),autolag='AIC') # .dropna() handles differenced data
    
    labels = ['ADF test statistic','p-value','# lags used','# observations']
    out = pd.Series(result[0:4],index=labels)

    for key,val in result[4].items():
        out[f'critical value ({key})']=val
        
    print(out.to_string())          # .to_string() removes the line "dtype: float64"
    
    if result[1] <= 0.05:
        print("Strong evidence against the null hypothesis")
        print("Reject the null hypothesis")
        print("Data has no unit root and is stationary")
    else:
        print("Weak evidence against the null hypothesis")
        print("Fail to reject the null hypothesis")
        print("Data has a unit root and is non-stationary")

# %% [markdown]
# ### Run the augmented Dickey-Fuller Test to confirm stationarity

# %%
adf_test(dfb_tir1_a['Number of individuals'])
# Out:
# Augmented Dickey-Fuller Test:
# ADF test statistic      -1.382600
# p-value                  0.590589
# # lags used              0.000000
# # observations          17.000000
# critical value (1%)     -3.889266
# critical value (5%)     -3.054358
# critical value (10%)    -2.666984
# Weak evidence against the null hypothesis
# Fail to reject the null hypothesis
# Data has a unit root and is non-stationary

# %% [markdown]
# ### Determine the (p,q) ARMA Orders using <tt>pmdarima.auto_arima</tt>

# %%
len(dfb_tir1_a)
# Out:
# 18

# %%
# Set 5 years for testing (25 %) 
train = dfb_tir1_a.iloc[:14]
test = dfb_tir1_a.iloc[14:]

# %%
train.head()
# Out:
#               Number of property interests1 Taxable income range4  \
# Income year2
# 2000-01-01                                1  b. $18,200 - $50,000
# 2001-01-01                                1  b. $18,200 - $50,000
# 2002-01-01                                1  b. $18,200 - $50,000
# 2003-01-01                                1  b. $18,200 - $50,000
# 2004-01-01                                1  b. $18,200 - $50,000
#
#               Number of individuals
# Income year2
# 2000-01-01                   446165
# 2001-01-01                   445059
# 2002-01-01                   448843
# 2003-01-01                   449916
# 2004-01-01                   450532

# %%
columns = ['Number of property interests1', 'Taxable income range4']

# %%
test = test.drop(columns, axis=1)
train = train.drop(columns, axis=1)

# %%
train.head() #2 unused columns dropped
# Out:
#               Number of individuals
# Income year2
# 2000-01-01                   446165
# 2001-01-01                   445059
# 2002-01-01                   448843
# 2003-01-01                   449916
# 2004-01-01                   450532

# %%
model = ARMA(train['Number of individuals'],order=(0,1))
results = model.fit()
results.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                                 ARMA Model Results
# ...
# Dep. Variable:     Number of individuals   No. Observations:                   14
# Model:                        ARMA(0, 1)   Log Likelihood                -150.056
# Method:                          css-mle   S.D. of innovations          10782.925
# Date:                   Fri, 01 Nov 2019   AIC                            306.113
# Time:                           23:32:00   BIC                            308.030
# Sample:                       01-01-2000   HQIC                           305.935
#                             - 01-01-2013
# ...
#                                   coef    std err          z      P>|z|      [0.025      0.975]
# -----------------------------------------------------------------------------------------------
# const                        4.326e+05   4394.724     98.446      0.000    4.24e+05    4.41e+05
# ...

# %% [markdown]
# ### Obtain 3 years worth of predicted values

# %%
start=len(train)
end=len(train)+len(test)-1

# %%
predictions = results.predict(start=start, end=end).rename('ARMA(0,1) Predictions')

# %%
title = 'Individuals are intersted in 1 property'
ylabel='Individuals'
xlabel='' # we don't really need a label here

ax = test['Number of individuals'].plot(legend=True,figsize=(12,6),title=title)
predictions.plot(legend=True)
ax.autoscale(axis='x',tight=True,)
ax.set(xlabel=xlabel, ylabel=ylabel);

# %% [markdown]
# ## Autoregressive Integrated Moving Average - ARIMA(p,d,q)
# The steps are the same as for ARMA(p,q), except that we'll apply a differencing component to make the dataset stationary.<br>
# First let's take a look at the <em>dfb_tir1_a</em> dataset.
# ### Plot the Source Data

# %%
 dfb_tir1_a['Number of individuals'].plot(figsize=(12,5))

# %%
from statsmodels.tsa.seasonal import seasonal_decompose

result = seasonal_decompose(dfb_tir1_a['Number of individuals'], model='additive')  # model='add' also works
result.plot();

# %% [markdown]
# No seasonality foundon the data and data is not residual

# %%
auto_arima(dfb_tir1_a['Number of individuals'],seasonal=False).summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                              ARIMA Model Results
# ...
# Dep. Variable:                    D.y   No. Observations:                   17
# Model:                 ARIMA(0, 1, 0)   Log Likelihood                -176.240
# Method:                           css   S.D. of innovations           7693.321
# Date:                Fri, 01 Nov 2019   AIC                            356.480
# Time:                        23:32:02   BIC                            358.146
# Sample:                             1   HQIC                           356.645
#
# ...
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const      -1475.1765   1865.904     -0.791      0.441   -5132.282    2181.929
# ...
# """

# %%
from statsmodels.tsa.statespace.tools import diff
dfb_tir1_a['d1'] = diff(dfb_tir1_a['Number of individuals'],k_diff=1)

# %%
adf_test(dfb_tir1_a['d1'])
# Out:
# Augmented Dickey-Fuller Test:
# ADF test statistic      -4.156052
# p-value                  0.000781
# # lags used              0.000000
# # observations          16.000000
# critical value (1%)     -3.924019
# critical value (5%)     -3.068498
# critical value (10%)    -2.673893
# Strong evidence against the null hypothesis
# Reject the null hypothesis
# Data has no unit root and is stationary

# %%
title = 'Autocorrelation: Number of Individuals'
lags = 17
plot_acf(dfb_tir1_a['Number of individuals'],title=title,lags=lags);

# %%
title = 'Partial Autocorrelation: Number of Individuals'
lags = 17
plot_pacf(dfb_tir1_a['Number of individuals'],title=title,lags=lags);

# %%
stepwise_fit = auto_arima(dfb_tir1_a['Number of individuals'], start_p=0, start_q=0,
                          max_p=2, max_q=2, m=12,
                          seasonal=False,
                          d=None, trace=True,
                          error_action='ignore',   # we don't want to know if an order does not work
                          suppress_warnings=True,  # we don't want convergence warnings
                          stepwise=True)           # set to stepwise

stepwise_fit.summary()
# Out:
# Fit ARIMA: order=(0, 1, 0); AIC=356.480, BIC=358.146, Fit time=0.003 seconds
# Fit ARIMA: order=(1, 1, 0); AIC=358.299, BIC=360.799, Fit time=0.059 seconds
# Fit ARIMA: order=(0, 1, 1); AIC=358.276, BIC=360.775, Fit time=0.014 seconds
# Fit ARIMA: order=(1, 1, 1); AIC=nan, BIC=nan, Fit time=nan seconds
# Total fit time: 0.120 seconds
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                              ARIMA Model Results
# ...
# Dep. Variable:                    D.y   No. Observations:                   17
# Model:                 ARIMA(0, 1, 0)   Log Likelihood                -176.240
# Method:                           css   S.D. of innovations           7693.321
# Date:                Fri, 01 Nov 2019   AIC                            356.480
# Time:                        15:33:45   BIC                            358.146
# Sample:                             1   HQIC                           356.645
#
# ...

# %% [markdown]
# Looks good from here! Now let's train & test the ARIMA(0,1,0) model, evaluate it, then produce a forecast of future values.
# ### Split the data into train/test sets

# %%
dfb_tir1_a.head(2)
# Out:
#               Number of property interests1 Taxable income range4  \
# Income year2
# 2000-01-01                                1  b. $18,200 - $50,000
# 2001-01-01                                1  b. $18,200 - $50,000
#
#               Number of individuals      d1
# Income year2
# 2000-01-01                   446165     NaN
# 2001-01-01                   445059 -1106.0

# %%
# Set 5 year for testing
train = dfb_tir1_a.iloc[:13]
test = dfb_tir1_a.iloc[13:]

# %%
columns = ['Number of property interests1', 'Taxable income range4','d1']
test = test.drop(columns, axis=1)
train = train.drop(columns, axis=1)

# %%
train = train.astype('float32')
test = test.astype('float32')

# %% [markdown]
# ### Fit an ARIMA(0,1,0) Model

# %%
model = ARIMA(train['Number of individuals'],order=(0,1,0))
results = model.fit()
results.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                                 ARIMA Model Results
# ...
# Dep. Variable:     D.Number of individuals   No. Observations:                   12
# Model:                      ARIMA(0, 1, 0)   Log Likelihood                -125.862
# Method:                                css   S.D. of innovations           8686.834
# Date:                     Fri, 01 Nov 2019   AIC                            255.724
# Time:                             15:37:52   BIC                            256.694
# Sample:                         01-01-2001   HQIC                           255.365
#                               - 01-01-2012
# ...
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const      -2333.4167   2507.673     -0.931      0.372   -7248.366    2581.532
# ...
# """

# %%
start = len(train)
end = len(train) + len(test) -1

# %%
predictions = results.predict(start= start, end = end, typ = 'levels').rename('ARIMA(0,1,0) Predictions')

# %%
predictions
# Out:
# 2013-01-01    415830.583333
# 2014-01-01    413497.166667
# 2015-01-01    411163.750000
# 2016-01-01    408830.333333
# 2017-01-01    406496.916667
# Freq: AS-JAN, Name: ARIMA(0,1,0) Predictions, dtype: float64

# %%
# Plot predictions against known values
title = 'Real vs Predicticted number of individuals'
ylabel='individuals number'
xlabel='' # we don't really need a label here

ax = test['Number of individuals'].plot(legend=True,figsize=(12,6),title=title)
predictions.plot(legend=True)
ax.autoscale(axis='x',tight=True)
ax.set(xlabel=xlabel, ylabel=ylabel)
# Out:
# [Text(0, 0.5, 'individuals number'), Text(0.5, 0, '')]

# %% [markdown]
# ### Evaluate the Model

# %%
test['Number of individuals'].mean()
# Out:
# 423864.4

# %%
predictions.mean()
# Out:
# 411163.74999999994

# %% [markdown]
# Test mean and prediction mean is close! Our model did a great job

# %%
from sklearn.metrics import mean_squared_error

error = mean_squared_error(test['Number of individuals'], predictions)
print(f'ARIMA(0,1,0) MSE Error: {error:11.10}')
# Out:
# ARIMA(0,1,0) MSE Error: 167712650.9

# %%
from statsmodels.tools.eval_measures import rmse

error = rmse(test['Number of individuals'], predictions)
print(f'ARIMA(0,1,0) RMSE Error: {error:11.10}')
# Out:
# ARIMA(0,1,0) RMSE Error: 12950.39192

# %% [markdown]
# ### Retraining the model on the full data, and forecast the future

# %%
columns = ['Number of property interests1', 'Taxable income range4','d1']
dfb_tir1_a = dfb_tir1_a.drop(columns, axis=1)

# %%
model3 = ARIMA(dfb_tir1_a['Number of individuals'],order=(0,1,0))

# %%
dfb_tir1_a.head(2)
# Out:
#               Number of individuals
# Income year2
# 2000-01-01                 446165.0
# 2001-01-01                 445059.0

# %%
dfb_tir1_a = dfb_tir1_a.astype('float64')

# %%
results3 = model3.fit()

# %%
fcast = results3.predict(len(dfb_tir1_a),len(dfb_tir1_a)+4,typ='levels').rename('ARIMA(0,1,0) Forecast')

# %%
# Plot predictions against known values
title = 'Real and Predicted number of individuals'
ylabel='Individuals'
#xlabel='' # we don't really need a label here

ax = dfb_tir1_a['Number of individuals'].plot(legend=True,figsize=(12,6),title=title)
fcast.plot(legend=True)
ax.autoscale(axis='x',tight=True)
ax.set(xlabel=xlabel, ylabel=ylabel)
# Out:
# [Text(0, 0.5, 'Individuals'), Text(0.5, 0, '')]

# %%
dfb_tir1_a.head()
# Out:
#               Number of individuals
# Income year2
# 2000-01-01                 446165.0
# 2001-01-01                 445059.0
# 2002-01-01                 448843.0
# 2003-01-01                 449916.0
# 2004-01-01                 450532.0

# %% [markdown]
# ## Linear Regression
# appliying linerar regression on the data(dfb_tir1_a) to predict number of individuals in future years

# %%
X = dfb_tir1[['Income year2', 'Number of property interests1']]
y = dfb_tir1[['Number of individuals']]

# %%
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3)

#creating and training the model

from sklearn.linear_model import LinearRegression

lm = LinearRegression()
lm.fit(X_train,y_train)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None, normalize=False)

# %%
predictions = lm.predict(X_test);
plt.scatter(y_test,predictions);

# %%
sns.distplot((y_test-predictions),bins=5);

# %% [markdown]
# ### Model evaluation

# %%
from sklearn import metrics
print('MAE:', metrics.mean_absolute_error(y_test, predictions))
print('MSE:', metrics.mean_squared_error(y_test, predictions))
print('RMSE:', np.sqrt(metrics.mean_squared_error(y_test, predictions)))
# Out:
# MAE: 15177.447978401402
# MSE: 241796806.9471344
# RMSE: 15549.81694256027

# %% [markdown]
# ## KNN to Predict Number of Property Interest

# %%
dfb.head()
# Out:
#    Income year2  Number of property interests1   Taxable income range4  \
# 0          2000                              1    a. Less than $18,200
# 1          2000                              1    b. $18,200 - $50,000
# 2          2000                              1   c. $50,001 - $100,000
# 3          2000                              1  d. $100,001 - $500,000
# 4          2000                              1   e. More than $500,000
#
#    Number of individuals
# 0                 224737
# 1                 446165
# 2                 180129
# 3                  36569
# 4                   1500

# %%
sns.pairplot(dfb,hue='Number of property interests1',palette='winter')

# %% [markdown]
# ##### Getting dummy data for Taxable income range  to train the model

# %%
dfb_dummy = pd.get_dummies(dfb)

# %%
dfb_dummy.head()
# Out:
#    Income year2  Number of property interests1  Number of individuals  \
# 0          2000                              1                 224737
# 1          2000                              1                 446165
# 2          2000                              1                 180129
# 3          2000                              1                  36569
# 4          2000                              1                   1500
#
#    Taxable income range4_a. Less than $18,200  \
# 0                                           1
# 1                                           0
# 2                                           0
# 3                                           0
# 4                                           0
#
#    Taxable income range4_b. $18,200 - $50,000  \
# 0                                           0
# 1                                           1
# 2                                           0
# 3                                           0
# ...

# %% [markdown]
# #### Standardize the Variables
#
# Because the KNN classifier predicts the class of a given test observation by identifying the observations that are nearest to it, the scale of the variables matters. Any variables that are on a large scale will have a much larger effect on the distance between the observations, and hence on the KNN classifier, than variables that are on a small scale.

# %%
from sklearn.preprocessing import StandardScaler

scaler = StandardScaler()

scaler.fit(dfb_dummy.drop('Number of property interests1',axis=1))
scaled_features = scaler.transform(dfb_dummy.drop('Number of property interests1',axis=1))

# %%
scaled_features
# Out:
# array([[-1.63835604,  1.53614679,  2.        , ..., -0.5       ,
#         -0.5       , -0.5       ],
#        [-1.63835604,  3.53989761, -0.5       , ..., -0.5       ,
#         -0.5       , -0.5       ],
#        [-1.63835604,  1.13247916, -0.5       , ...,  2.        ,
#         -0.5       , -0.5       ],
#        ...,
#        [ 1.63835604, -0.44559633, -0.5       , ...,  2.        ,
#         -0.5       , -0.5       ],
#        [ 1.63835604, -0.43958764, -0.5       , ..., -0.5       ,
#          2.        , -0.5       ],
#        [ 1.63835604, -0.49129489, -0.5       , ..., -0.5       ,
#         -0.5       ,  2.        ]])

# %%
dfb_dummy.columns
# Out:
# Index(['Income year2', 'Number of property interests1',
#        'Number of individuals', 'Taxable income range4_a. Less than $18,200',
#        'Taxable income range4_b. $18,200 - $50,000',
#        'Taxable income range4_c. $50,001 - $100,000',
#        'Taxable income range4_d. $100,001 - $500,000',
#        'Taxable income range4_e. More than $500,000'],
#       dtype='object')

# %%
#Rearranging columns to fit into the model
dfb_dummy = dfb_dummy[['Income year2','Number of individuals', 'Taxable income range4_a. Less than $18,200',
       'Taxable income range4_b. $18,200 - $50,000',
       'Taxable income range4_c. $50,001 - $100,000',
       'Taxable income range4_d. $100,001 - $500,000',
       'Taxable income range4_e. More than $500,000','Number of property interests1']]

# %%
dfb_dummy.head()
# Out:
#    Income year2  Number of individuals  \
# 0          2000                 224737
# 1          2000                 446165
# 2          2000                 180129
# 3          2000                  36569
# 4          2000                   1500
#
#    Taxable income range4_a. Less than $18,200  \
# 0                                           1
# 1                                           0
# 2                                           0
# 3                                           0
# 4                                           0
#
#    Taxable income range4_b. $18,200 - $50,000  \
# 0                                           0
# 1                                           1
# 2                                           0
# 3                                           0
# 4                                           0
#
#    Taxable income range4_c. $50,001 - $100,000  \
# 0                                            0
# 1                                            0
# ...

# %%
df_feat = pd.DataFrame(scaled_features,columns=dfb_dummy.columns[:-1])
df_feat.head()
# Out:
#    Income year2  Number of individuals  \
# 0     -1.638356               1.536147
# 1     -1.638356               3.539898
# 2     -1.638356               1.132479
# 3     -1.638356              -0.166627
# 4     -1.638356              -0.483974
#
#    Taxable income range4_a. Less than $18,200  \
# 0                                         2.0
# 1                                        -0.5
# 2                                        -0.5
# 3                                        -0.5
# 4                                        -0.5
#
#    Taxable income range4_b. $18,200 - $50,000  \
# 0                                        -0.5
# 1                                         2.0
# 2                                        -0.5
# 3                                        -0.5
# 4                                        -0.5
#
#    Taxable income range4_c. $50,001 - $100,000  \
# 0                                         -0.5
# 1                                         -0.5
# ...

# %% [markdown]
# ### Train Test Split

# %%
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(scaled_features,dfb_dummy['Number of property interests1'],
                                                    test_size=0.30)

# %%
## KNN applying initial k value = 1 
from sklearn.neighbors import KNeighborsClassifier

knn = KNeighborsClassifier(n_neighbors=1)

# %%
knn.fit(X_train,y_train)
# Out:
# KNeighborsClassifier(algorithm='auto', leaf_size=30, metric='minkowski',
#                      metric_params=None, n_jobs=None, n_neighbors=1, p=2,
#                      weights='uniform')

# %%
pred = knn.predict(X_test)

# %% [markdown]
# ### Prediction and evaluation

# %%
from sklearn.metrics import classification_report,confusion_matrix

# %%
print(confusion_matrix(y_test,pred))
# Out:
# [[21  7  2  1  0  0]
#  [ 0 19  7  2  0  0]
#  [ 0  0  4 17  4  4]
#  [ 0  0  0  1 12 11]
#  [ 0  0  0  5  1 17]
#  [ 0  0  0  8 19  0]]

# %% [markdown]
# ### Choosing a K Value
#
# Using the elbow method to pick a good K Value:

# %%
error_rate = []

# Will take some time
for i in range(1,40):
    
    knn = KNeighborsClassifier(n_neighbors=i)
    knn.fit(X_train,y_train)
    pred_i = knn.predict(X_test)
    error_rate.append(np.mean(pred_i != y_test))

# %%
plt.figure(figsize=(10,6))
plt.plot(range(1,40),error_rate,color='blue', linestyle='dashed', marker='o',
         markerfacecolor='red', markersize=10)
plt.title('Error Rate vs. K Value')
plt.xlabel('K')
plt.ylabel('Error Rate')
# Out:
# Text(0, 0.5, 'Error Rate')

# %% [markdown]
# Here we can see that that after around K = 4 the error rate going upwards! K = 4 is perfect

# %%
# FIRST A QUICK COMPARISON TO OUR ORIGINAL K=1
knn = KNeighborsClassifier(n_neighbors=1)

knn.fit(X_train,y_train)
pred = knn.predict(X_test)

print('WITH K=1')
print('\n')
print(confusion_matrix(y_test,pred))
print('\n')
print(classification_report(y_test,pred))
# Out:
# WITH K=1
#
#
# [[21  7  2  1  0  0]
#  [ 0 19  7  2  0  0]
#  [ 0  0  4 17  4  4]
#  [ 0  0  0  1 12 11]
#  [ 0  0  0  5  1 17]
#  [ 0  0  0  8 19  0]]
#
#
#               precision    recall  f1-score   support
#
#            1       1.00      0.68      0.81        31
#            2       0.73      0.68      0.70        28
#            3       0.31      0.14      0.19        29
#            4       0.03      0.04      0.03        24
#            5       0.03      0.04      0.03        23
#            6       0.00      0.00      0.00        27
#
#     accuracy                           0.28       162
#    macro avg       0.35      0.26      0.30       162
# weighted avg       0.38      0.28      0.32       162

# %%
# NOW WITH K=4
knn = KNeighborsClassifier(n_neighbors=4)

knn.fit(X_train,y_train)
pred = knn.predict(X_test)

print('WITH K=4')
print('\n')
print(confusion_matrix(y_test,pred))
print('\n')
print(classification_report(y_test,pred))
# Out:
# WITH K=4
#
#
# [[21  9  1  0  0  0]
#  [ 3 20  5  0  0  0]
#  [ 3  1 13  8  3  1]
#  [ 2  1  7  6  5  3]
#  [ 0  2  3  5  4  9]
#  [ 2  0  4  5 13  3]]
#
#
#               precision    recall  f1-score   support
#
#            1       0.68      0.68      0.68        31
#            2       0.61      0.71      0.66        28
#            3       0.39      0.45      0.42        29
#            4       0.25      0.25      0.25        24
#            5       0.16      0.17      0.17        23
#            6       0.19      0.11      0.14        27
#
#     accuracy                           0.41       162
#    macro avg       0.38      0.40      0.38       162
# weighted avg       0.40      0.41      0.40       162

# %% [markdown]
# # Summary
#
# Taxable income range (27B): In table 27B we saw those who has taxable income range below 18000 dollars their amount was not increasing over the time period 1999-2017. But when it comes to taxable income range 18000-50000 dollars the number of individual with single property interest was decreasing significantly over the time period. We did not found any seasonality on the data and data was stationary. The data was stationary non seasonal. Later we used Linear Regression, ARMA, ARIMA and KNN to predict number of individuals for 3 years in future.
